# %% [markdown]
# <a href="https://colab.research.google.com/github/febriantimayori/PCVK_Ganjil_2024/blob/main/Week01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Modul 1 – Penggunaan Github dan Google Colaboratory, Membaca dan Menampilkan Citra**
#
# > Nama: Febrianti Mayori
#
# > NIM: 2241720248
#
# > Kelas TI-3D

# %% [markdown]
# ### **Langkah (Step) 1: Import beberapa library yang akan digunakan adalah numpy, pandas, cv2, skimage, PIL, matplotlib.**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io, transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# ### **Langkah (Step) 2: Membaca Image dari URLs.**

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://assets.rebelmouse.io/eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpbWFnZSI6Imh0dHBzOi8vYXNzZXRzLnJibC5tcy80MTQwNzA5L29yaWdpbi5qcGciLCJleHBpcmVzX2F0IjoxNzI4MDQ5MjAyfQ.HCk1uahPNm1ne0lNFZxAABdwt_kuuKHus9ZBXDlsqRA/img.jpg?width=600&quality=85"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=600x366>

# %% [markdown]
# ### **Langkah (Step) 3: Melihat ukuran File Image.**

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar =  366  x  300
# <PIL.Image.Image image mode=RGB size=300x366>

# %% [markdown]
# ### **Langkah (Step) 4: Mengakses pixel dengan memberi garis diagonal menyilang.**

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi) / 2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x366>

# %% [markdown]
# ### **Pertanyaan**
#
#
# 1.   Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
# > * Dengan menggunakan Google Colab kita tidak perlu memikirkan resource yang
# terbatas pada komputer kita.
# > * Mudah untuk diintergrasikan dengan tools lainnya seperti Github.
# > * Package Python juga sudah terinstall pada Google Colab.
# > * Kita juga memerlukan fungsi dari google.colab.patches yaitu cv2_imshow.
# > * Sehingga, untuk praktikum kali ini lebih mudah dalam menggunakan Google Colab.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# > * import numpy as np mengimpor library Numpy yang akan digunakan untuk manipulasi data numerik.
# > * import pandas as pd mengimpor library Pandas yang akan digunakan untuk memanipulasi dan analisis data tabular.
# > * import cv2 as cv mengimpor library OpenCV yang akan digunakan untuk pemrosesan gambar dan video.
# > * from google.colab.patches import cv2_imshow memungkinkan anda untuk menampilkan gambar menggunakan OpenCV dalam environment Google Colab.
# > * from skimage import io, transform mengimpor library scikit-image yang akan digunakan untuk manipulasi dan pemrosesan gambar.
# > * from PIL import Image mengimpor library Python Imaging Library (PIL) yang akan digunakan untuk membuka dan menyimpan gambar.
# > * import matplotlib.pylab as plt mengimpor library Matplotlib yang akan digunakan untuk visualisasi data.
# > * Pada praktikum ini tidak semua library harus digunakan. Contohnya, untuk matplotlib tidak kita gunakan pada praktikum ini karena kita tidak melakukan visualisasi data. Kemudian, untuk numpy, kita belum menggunakannya untuk memanipulasi data numerik.
#
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# ```
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# ```
# Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
# > Digunakan untuk mengubah ukuran image menjadi setengah dari ukuran aslinya. Jika tidak dilakukan maka akan menampilkan dari ukuran aslinya. Contohnya: Gambar kucing di atas memiliki ukuran 286 * 400 setelah di resize. Namun, akan memiliki resolusi image sebesar tinggi x lebar = 571 x 800, jika tidak dilakukan resizing image menggunakan kode di atas.
#
#
# 4. Perhatikan potongan kode program berikut:
# ```
# for y in range (lebar):
#   image_3[int((tinggi) / 2), y] = [255,255,255]
# ```
# Apakah kegunaan kode [255, 255, 255]? Jelaskan!
# > Kegunaan kode tersebut adalah untuk mengganti 3 layer dari gambar menjadi 255,255,255. Hal itu bermaksud bahwa layer R, G dan B akan memiliki nilai 255, dimana nilai 255, 255, 255 akan menghasilkan warna putih. Jadi, kode tersebut adalah untuk mengganti warna pixel dari warna asli menjadi warna putih.
#
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# > Resolusi gambar adalah jumlah pixel yang digunakan untuk membentuk sebuah gambar, dalam hal ini resolusi mempengaruhi kualitas gambar. Gambar dengan resolusi tinggi memiliki jumlah pixel yang lebih banyak begitupun sebaliknya. Sehingga, gambar dengan resolusi tinggi akan memiliki tampilan yang lebih jelas dan detail dibandingkan dengan gambar dengan resolusi rendah.

# %% [markdown]
# ### **E. TUGAS**
# 1. Lakukan langkah-langkah praktikum seperti diatas!

# %%
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_5[x, int((lebar) / 2)] = [255,255,255]


final_frame_2 = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame_2)
# Out:
# <PIL.Image.Image image mode=RGB size=600x366>

# %% [markdown]
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran!

# %%
image_7 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_7 = cv.line(image_7,(0,0),(lebar,tinggi),[255,255,255],1)
image_7 = cv.line(image_7,(0,tinggi),(lebar,0),[255,255,255],1)


final_frame_6 = cv.hconcat((image_2, image_7))
cv2_imshow(final_frame_6)
# Out:
# <PIL.Image.Image image mode=RGB size=600x366>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu.

# %%
image_8 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(100, 200):
  image_8[int((tinggi) / 2), y] = [255,255,255]

final_frame_4 = cv.hconcat((image_2, image_8))
cv2_imshow(final_frame_4)
# Out:
# <PIL.Image.Image image mode=RGB size=600x366>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar.

# %%
image_9 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(100, 200):
  for x in range (100, 200):
    image_9[x, y] = [255,255,255]


final_frame_5 = cv.hconcat((image_2, image_9))
cv2_imshow(final_frame_5)
# Out:
# <PIL.Image.Image image mode=RGB size=600x366>

# %% [markdown]
# # **Tugas Kelompok**
# Saya mencoba untuk menutupi bagian TTL dan Jenis Kelamin dari kartu identitas berikut.

# %%
import cv2 as cv
from skimage import io
import requests
import numpy as np
from PIL import Image
import io as io_pil
import matplotlib.pyplot as plt

# Download image from URL
image_url = "https://about.lovia.id/wp-content/uploads/2020/05/ktp-768x495.jpg"
response = requests.get(image_url)

# Convert image from bytes to a NumPy array
image_data = np.array(Image.open(io_pil.BytesIO(response.content)))

# Convert the image to OpenCV format (RGB to BGR)
image_rgb1 = cv.cvtColor(image_data, cv.COLOR_RGB2BGR)
image_rgb2 = cv.cvtColor(image_data, cv.COLOR_RGB2BGR)

# Menutupi bagian TTL (Tempat Tanggal Lahir)
start_x_ttl = 195  # X mulai dari TTL
start_y_ttl = 165  # Y mulai dari TTL
width_box_ttl = 210  # Lebar kotak penutup TTL
height_box_ttl = 17  # Tinggi kotak penutup TTL

for i in range(height_box_ttl):
    for j in range(width_box_ttl):
        image_rgb2[start_y_ttl + i, start_x_ttl + j] = [255, 0, 0]  # Tutup TTL dengan warna merah

# Menutupi bagian Jenis Kelamin
start_x_jk = 195  # X mulai dari Jenis Kelamin
start_y_jk = 190  # Y mulai dari Jenis Kelamin
width_box_jk = 120  # Lebar kotak penutup Jenis Kelamin
height_box_jk = 15  # Tinggi kotak penutup Jenis Kelamin

for i in range(height_box_jk):
    for j in range(width_box_jk):
        image_rgb2[start_y_jk + i, start_x_jk + j] = [0, 255, 255]  # Tutup Jenis Kelamin dengan warna kuning

# Gabungkan gambar asli dan gambar yang telah diedit
combined_frame = cv.hconcat((image_rgb1, image_rgb2))

# Convert back to RGB for matplotlib
combined_frame_rgb = cv.cvtColor(combined_frame, cv.COLOR_BGR2RGB)

# Tampilkan gambar menggunakan matplotlib
plt.imshow(combined_frame_rgb)
plt.axis('off')  # Hide axes
plt.show()
